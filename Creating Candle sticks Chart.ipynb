# %%
import pandas as pd
import yfinance as yf
import mplfinance as mf

# %%
data = yf.download('ENDURANCE.ns',start='2021-01-01',end='2021-08-20',index_col = 'Date',parse_dates=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
mf.plot(data,
       type = 'candle',
       title = 'Endurance Tech Chart',
       figsize = (16,8),
       style = 'yahoo',
       volume = True,
       mav = 30)
